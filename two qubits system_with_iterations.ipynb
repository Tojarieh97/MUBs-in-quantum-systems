# %%
from qiskit.circuit.library.standard_gates import RXGate, RZGate, RYGate, CXGate, CZGate, SGate, HGate
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister

import numpy as np

# %%
from qiskit import Aer
from qiskit.utils import QuantumInstance, algorithm_globals

seed = 50
algorithm_globals.random_seed = seed

simulator_backend = Aer.get_backend('qasm_simulator')

# %%
def get_linear_entangelment_ansatz(num_of_qubits, thetas, input_state, circuit_depth=3):
    quantum_register = QuantumRegister(num_of_qubits, name="qubit")
    quantum_circuit = QuantumCircuit(quantum_register)
    quantum_circuit.initialize(input_state)

    for iteration in range(circuit_depth):
        for qubit_index in range(num_of_qubits):
            RY_theta_index = iteration*2*num_of_qubits + qubit_index
            RZ_theta_index = RY_theta_index + num_of_qubits
            
            quantum_circuit.append(RYGate(thetas[RY_theta_index]), [quantum_register[qubit_index]])
            quantum_circuit.append(RZGate(thetas[RZ_theta_index]), [quantum_register[qubit_index]])
            
        for qubit_index in range(num_of_qubits - 1):
            quantum_circuit.append(CXGate(), [quantum_register[qubit_index], quantum_register[qubit_index + 1]])

    for qubit_index in range(num_of_qubits):
            RY_theta_index = 2*num_of_qubits*circuit_depth + qubit_index
            RZ_theta_index = RY_theta_index + num_of_qubits
            quantum_circuit.append(RYGate(thetas[RY_theta_index]), [quantum_register[qubit_index]])
            quantum_circuit.append(RZGate(thetas[RZ_theta_index]), [quantum_register[qubit_index]])

    return quantum_circuit

# %%
def get_full_entangelment_ansatz(num_of_qubits, thetas, input_state, circuit_depth=3):
    quantum_register = QuantumRegister(num_of_qubits, name="qubit")
    quantum_circuit = QuantumCircuit(quantum_register)
    quantum_circuit.initialize(input_state)

    for iteration in range(circuit_depth):
        for qubit_index in range(num_of_qubits):
            RY_theta_index = iteration*2*num_of_qubits + qubit_index
            RZ_theta_index = RY_theta_index + num_of_qubits
            
            quantum_circuit.append(RYGate(thetas[RY_theta_index]), [quantum_register[qubit_index]])
            quantum_circuit.append(RZGate(thetas[RZ_theta_index]), [quantum_register[qubit_index]])
        for qubit_index in range(num_of_qubits - 1):
            for target_qubit_index in range(qubit_index + 1, num_of_qubits):
                quantum_circuit.append(CXGate(), [quantum_register[qubit_index], quantum_register[target_qubit_index]])

    for qubit_index in range(num_of_qubits):
            RY_theta_index = 2*num_of_qubits*circuit_depth + qubit_index
            RZ_theta_index = RY_theta_index + num_of_qubits
            
            quantum_circuit.append(RYGate(thetas[RY_theta_index]), [quantum_register[qubit_index]])
            quantum_circuit.append(RZGate(thetas[RZ_theta_index]), [quantum_register[qubit_index]])

    return quantum_circuit

# %%
QUBITS_NUM = 2
N = 2**QUBITS_NUM

NUM_SHOTS = 1024
NUM_ITERATIONS = 50

CIRCUIT_DEPTH = 3
PARAMS_NUM = 2*QUBITS_NUM*(CIRCUIT_DEPTH+1)

# %% [markdown]
# #### convert hamiltonian to pauli strings

# %%
from typing import Dict, Tuple, List

# %%
def transfrom_hamiltonian_into_pauli_strings(hamiltonian) -> List:
    pauli_operators = hamiltonian.to_pauli_op().settings['oplist']
    pauli_coeffs = list(map(lambda pauli_operator: pauli_operator.coeff, pauli_operators))
    pauli_strings = list(map(lambda pauli_operator: pauli_operator.primitive, pauli_operators))
    return pauli_coeffs, pauli_strings

# %%
reducing_to_pauli_z_mapping = {
    'I': 'I',
    'Z': 'Z',
    'X': 'Z',
    'Y': 'Z'
}

# %%
def reduce_pauli_matrixes_into_sigma_z(pauli_string) -> str:
    reduced_pauli_string = ""
    for matrix_index in range(QUBITS_NUM):
        pauli_matrix = str(pauli_string[matrix_index])
        reduced_pauli_matrix = reducing_to_pauli_z_mapping[pauli_matrix]
        reduced_pauli_string = reduced_pauli_matrix + reduced_pauli_string
    
    return reduced_pauli_string

# %%
def add_layer_of_gates_for_reducing_paulis_to_sigma_z(pauli_string, quantum_circuit):
    quantum_registers = QuantumRegister(QUBITS_NUM, name="qubit")
    additional_circuit_layer = QuantumCircuit(quantum_registers)
    
    for quantum_register_index, pauli_matrix in enumerate(pauli_string):
        if pauli_matrix == "X":
            additional_circuit_layer.append(HGate(), [quantum_registers[quantum_register_index]])
        if pauli_string == "Y":
            additional_circuit_layer.append(HGate(), [quantum_registers[quantum_register_index]])
            additional_circuit_layer.append(SGate(), [quantum_registers[quantum_register_index]])
                
    extended_quantum_circuit = quantum_circuit.compose(additional_circuit_layer)
    return extended_quantum_circuit

# %% [markdown]
# #### probabilities distribution

# %%
from qiskit import assemble, transpile

# %%
def get_probability_distribution(counts: Dict) -> Dict:
    proba_distribution = {state: (count / NUM_SHOTS) for state, count in counts.items()}
    return proba_distribution

def calculate_probabilities_of_measurments_in_computational_basis(quantum_state_circuit) -> Dict:
    quantum_state_circuit.measure_all()
    
    transpiled_quantum_state_circuit = transpile(quantum_state_circuit, simulator_backend) 
    Qobj = assemble(transpiled_quantum_state_circuit)
    result = simulator_backend.run(Qobj).result()
    counts = result.get_counts(quantum_state_circuit)
    
    return get_probability_distribution(counts)

# %% [markdown]
# #### Expectation value from probabilities

# %%
def sort_probas_dict_by_qubits_string_keys(proba_distribution: Dict) -> Dict:
    return dict(sorted(proba_distribution.items()))

def reset_power_of_minus_1(power_of_minus_1):
    power_of_minus_1 = 0
    return power_of_minus_1

def convert_pauli_string_into_str(pauli_string) -> str:
    return str(pauli_string)

def calculate_expectation_value_of_pauli_string_by_measurments_probas(pauli_string, ansatz_circuit):
    pauli_string_expectation_value = 0
    power_of_minus_1 = 0
    
    pauli_string_str = convert_pauli_string_into_str(pauli_string)
    extended_ansatz_circuit = add_layer_of_gates_for_reducing_paulis_to_sigma_z(pauli_string_str, ansatz_circuit)
    probas_distribution = calculate_probabilities_of_measurments_in_computational_basis(extended_ansatz_circuit)
    
    reduced_pauli_string = reduce_pauli_matrixes_into_sigma_z(pauli_string)
    sorted_probas_distribuition = sort_probas_dict_by_qubits_string_keys(probas_distribution)
    for qubits_string, proba in sorted_probas_distribuition.items():
        for string_index in range(QUBITS_NUM):
            if(str(qubits_string[string_index])=="1" and str(reduced_pauli_string[string_index])=="Z"):
                power_of_minus_1 += 1
            
        pauli_string_expectation_value += pow(-1, power_of_minus_1)*proba
        power_of_minus_1 = reset_power_of_minus_1(power_of_minus_1)
        
    return pauli_string_expectation_value

# %%
def get_expectation_value(ansatz_circuit, pauli_coeffs, pauli_strings):
    total_expection_value = 0
    
    for pauli_coeff, pauli_string in zip(pauli_coeffs, pauli_strings):
        total_expection_value += pauli_coeff*calculate_expectation_value_of_pauli_string_by_measurments_probas(
                                                                                    pauli_string, ansatz_circuit)
    
    return total_expection_value

# %% [markdown]
# ## MUBs d=4

# %%
from typing import List

class MUB:
    def __init__(self, name: str, color: str, basis_vectors, dim: int):
        self.name = name
        self.color = color
        self.basis_vectors = basis_vectors
        self.results = []
        
    def add_result(self, result:int):
        self.results.append(result)
        
    def restart_results(self):
        self.results = []

# %%
M0_vectors = np.identity(N)

M1_vectors = [np.vectorize(complex)([0.5,0.5,0.5,0.5]),
      np.vectorize(complex)([0.5,0.5,-0.5,-0.5]),
      np.vectorize(complex)([0.5,-0.5,-0.5,0.5]),
      np.vectorize(complex)([0.5,-0.5,0.5,-0.5])]

M2_vectors = [np.vectorize(complex)([0.5,0.5,0,0],[0,0,-0.5,-0.5]),
      np.vectorize(complex)([0.5,-0.5,0,0],[0,0,0.5,0.5]),
      np.vectorize(complex)([0.5,0.5,0,0],[0,0,0.5,-0.5]),
      np.vectorize(complex)([0.5,0.5,0,0],[0,0,-0.5,0.5])]

M3_vectors = [np.vectorize(complex)([0.5,0,0,-0.5],[0,-0.5,-0.5,-0]),
      np.vectorize(complex)([0.5,0,0,0.5],[0,-0.5,0.5,0]),
      np.vectorize(complex)([0.5,0,0,-0.5],[0,0.5,0.5,0]),
      np.vectorize(complex)([0.5,0,0,0.5],[0,0.5,-0.5,0])]

M4_vectors = [np.vectorize(complex)([0.5,0,-0.5,0],[0,-0.5,0,-0.5]),
      np.vectorize(complex)([0.5,0,0.5,0],[0,-0.5,0,0.5]),
      np.vectorize(complex)([0.5,0,-0.5,0],[0,0.5,0,0.5]),
      np.vectorize(complex)([0.5,0,0.5,0],[0,0.5,0,-0.5])]

# %%
M0 = MUB(name='M0', color='b', basis_vectors=M0_vectors, dim=4)
M1 = MUB(name='M1', color='c', basis_vectors=M1_vectors, dim=4)
M2 = MUB(name='M2', color='y', basis_vectors=M2_vectors, dim=4)
M3 = MUB(name='M3', color='m', basis_vectors=M3_vectors, dim=4)
M4 = MUB(name='M4', color='r', basis_vectors=M4_vectors, dim=4)

mubs_d_5 = [M0, M1, M2, M3, M4]

# %% [markdown]
# ### H2 Molecule 2 qubits

# %%
from matplotlib import pyplot as plt

# %%
from qiskit.opflow import X, Z, I

H2_molecule_Hamiltonian_2_qubits = -0.5053051899926562*(I^I) + \
                            -0.3277380754984016*(Z^I) + \
                            0.15567463610622564*(Z^Z) + \
                            -0.3277380754984016*(I^Z)

print(H2_molecule_Hamiltonian_2_qubits)
# Out:
# -0.5053051899926562 * II
# - 0.3277380754984016 * ZI
# + 0.15567463610622564 * ZZ
# - 0.3277380754984016 * IZ

# %%
thetas = np.random.uniform(low=0, high=360, size=PARAMS_NUM)

# %% [markdown]
# ### full entangelment

# %%
for basis in mubs_d_5:
    basis.restart_results()
    for vector in basis.basis_vectors:
        pauli_coeffs, pauli_strings = transfrom_hamiltonian_into_pauli_strings(H2_molecule_Hamiltonian_2_qubits)
        ansatz_state = get_full_entangelment_ansatz(QUBITS_NUM, thetas, vector)

        L = get_expectation_value(ansatz_state, pauli_coeffs, pauli_strings)
        basis.add_result(L)
# Out:
# Result(backend_name='qasm_simulator', backend_version='0.11.1', qobj_id
success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 521, '0x3': 343, '0x1': 41, '0x2': 119}), header=QobjExperimentHeader(clbit_labels=[['meas', 0], ['meas', 1]], creg_sizes=[['meas', 2]], global_phase=1.2719703568328047, memory_slots=2, metadata={}, n_qubits=2, name='circuit-64751', qreg_sizes=[['qubit', 2]], qubit_labels=[['qubit', 0], ['qubit', 1]]), status=DONE, seed_simulator=2190387388, metadata={'batched_shots_optimization': False, 'method': 'statevector', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'sample_measure_time': 0.0010598, 'input_qubit_map': [[0, 0], [1, 1]], 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'fusion': {'enabled': True, 'threshold': 14, 'max_fused_qubits': 5, 'applied': False}}, time_taken=0.0135071)], date=2022-12-09T15:19:22.739684, status=COMPLETED, header=None, metadata={'parallel_experiments': 1, 'omp_enabled': True, 'max_memory_mb': 16110, 'max_gpu_memory_mb': 0, 'num_processes_per_experiments': 1, 'time_taken_load_qobj': 0.0004165, 'mpi_rank': 0, 'num_mpi_processes': 1, 'time_taken_execute': 0.0137232, 'time_taken': 0.0141642}, time_taken=0.014510631561279297)
# {'00': 0.5087890625, '01': 0.0400390625, '10': 0.1162109375, '11': 0.3349609375}
# Result(backend_name='qasm_simulator', backend_version='0.11.1', qobj_id='10198ece-8dd5-4c00-844f-c8880cccef78', job_id='3ba2921f-7ceb-452d-9369-cdd53f1b38ba', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x1': 561, '0x2': 401, '0x3': 16, '0x0': 46}), header=QobjExperimentHeader(clbit_labels=[['meas', 0], ['meas', 1]], creg_sizes=[['meas', 2]], global_phase=1.2719703568328047, memory_slots=2, metadata={}, n_qubits=2, name='circuit-65336', qreg_sizes=[['qubit', 2]], qubit_labels=[['qubit', 0], ['qubit', 1]]), status=DONE, seed_simulator=1265346927, metadata={'batched_shots_optimization': False, 'method': 'statevector', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'sample_measure_time': 0.0009687, 'input_qubit_map': [[0, 0], [1, 1]], 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'fusion': {'enabled': True, 'threshold': 14, 'max_fused_qubits': 5, 'applied': False}}, time_taken=0.0051773)], date=2022-12-09T15:19:22.979804, status=COMPLETED, header=None, metadata={'parallel_experiments': 1, 'omp_enabled': True, 'max_memory_mb': 16110, 'max_gpu_memory_mb': 0, 'num_processes_per_experiments': 1, 'time_taken_load_qobj': 0.0003614, 'mpi_rank': 0, 'num_mpi_processes': 1, 'time_taken_execute': 0.005434, 'time_taken': 0.0058119}, time_taken=0.006211996078491211)
# {'00': 0.044921875, '01': 0.5478515625, '10': 0.3916015625, '11': 0.015625}
# Result(backend_name='qasm_simulator', backend_version='0.11.1', qobj_id='6b587911-40c6-437e-bbc5-885aeb889a25', job_id='ffd40d90-d0b8-4ee1-ab21-1e5ccb754ed3', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x2': 422, '0x1': 549, '0x3': 14, '0x0': 39}), header=QobjExperimentHeader(clbit_labels=[['meas', 0], ['meas', 1]], creg_sizes=[['meas', 2]], global_phase=1.2719703568328047, memory_slots=2, metadata={}, n_qubits=2, name='circuit-65336', qreg_sizes=[['qubit', 2]], qubit_labels=[['qubit', 0], ['qubit', 1]]), status=DONE, seed_simulator=296428575, metadata={'batched_shots_optimization': False, 'method': 'statevector', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'sample_measure_time': 0.0010868, 'input_qubit_map': [[0, 0], [1, 1]], 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'fusion': {'enabled': True, 'threshold': 14, 'max_fused_qubits': 5, 'applied': False}}, time_taken=0.0054743)], date=2022-12-09T15:19:23.106471, status=COMPLETED, header=None, metadata={'parallel_experiments': 1, 'omp_enabled': True, 'max_memory_mb': 16110, 'max_gpu_memory_mb': 0, 'num_processes_per_experiments': 1, 'time_taken_load_qobj': 0.0003745, 'mpi_rank': 0, 'num_mpi_processes': 1, 'time_taken_execute': 0.0056574, 'time_taken': 0.0060481}, time_taken=0.006629228591918945)
# {'00': 0.0380859375, '01': 0.5361328125, '10': 0.412109375, '11': 0.013671875}
# Result(backend_name='qasm_simulator', backend_version='0.11.1', qobj_id='5a13be08-70a8-4a01-893d-6069397f6e1f', job_id='b860ca5a-95b8-4991-9859-bb637503d2af', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x1': 567, '0x2': 392, '0x0': 45, '0x3': 20}), header=QobjExperimentHeader(clbit_labels=[['meas', 0], ['meas', 1]], creg_sizes=[['meas', 2]], global_phase=1.2719703568328047, memory_slots=2, metadata={}, n_qubits=2, name='circuit-65336', qreg_sizes=[['qubit', 2]], qubit_labels=[['qubit', 0], ['qubit', 1]]), status=DONE, seed_simulator=3421773414, metadata={'batched_shots_optimization': False, 'method': 'statevector', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'sample_measure_time': 0.0011416, 'input_qubit_map': [[0, 0], [1, 1]], 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'fusion': {'enabled': True, 'threshold': 14, 'max_fused_qubits': 5, 'applied': False}}, time_taken=0.0051233)], date=2022-12-09T15:19:23.444961, status=COMPLETED, header=None, metadata={'parallel_experiments': 1, 'omp_enabled': True, 'max_memory_mb': 16110, 'max_gpu_memory_mb': 0, 'num_processes_per_experiments': 1, 'time_taken_load_qobj': 0.0003492, 'mpi_rank': 0, 'num_mpi_processes': 1, 'time_taken_execute': 0.0052832, 'time_taken': 0.0056539}, time_taken=0.005945444107055664)
# {'00': 0.0439453125, '01': 0.5537109375, '10': 0.3828125, '11': 0.01953125}
# Result(backend_name='qasm_simulator', backend_version='0.11.1', qobj_id='dfdaf4b8-1a52-4dfd-8531-f124313d0633', job_id='7739f370-3ff7-40af-adc4-bd7ab11d6222', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x2': 427, '0x1': 539, '0x0': 46, '0x3': 12}), header=QobjExperimentHeader(clbit_labels=[['meas', 0], ['meas', 1]], creg_sizes=[['meas', 2]], global_phase=1.2719703568328047, memory_slots=2, metadata={}, n_qubits=2, name='circuit-65336', qreg_sizes=[['qubit', 2]], qubit_labels=[['qubit', 0], ['qubit', 1]]), status=DONE, seed_simulator=3674261090, metadata={'batched_shots_optimization': False, 'method': 'statevector', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'sample_measure_time': 0.0014609, 'input_qubit_map': [[0, 0], [1, 1]], 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'fusion': {'enabled': True, 'threshold': 14, 'max_fused_qubits': 5, 'applied': False}}, time_taken=0.0081454)], date=2022-12-09T15:19:23.560303, status=COMPLETED, header=None, metadata={'parallel_experiments': 1, 'omp_enabled': True, 'max_memory_mb': 16110, 'max_gpu_memory_mb': 0, 'num_processes_per_experiments': 1, 'time_taken_load_qobj': 0.0046331, 'mpi_rank': 0, 'num_mpi_processes': 1, 'time_taken_execute': 0.0083978, 'time_taken': 0.0130515}, time_taken=0.013859748840332031)
# {'00': 0.044921875, '01': 0.5263671875, '10': 0.4169921875, '11': 0.01171875}

# %%
M0_points = plt.scatter(x=range(1,5),y=M0.results, marker='x', color=M0.color)
M1_points = plt.scatter(x=range(5,9),y=M1.results, marker='x', color=M1.color)
M2_points = plt.scatter(x=range(10,14),y=M2.results, marker='x', color=M2.color)
M3_points = plt.scatter(x=range(15,19),y=M3.results, marker='x', color=M3.color)
M4_points = plt.scatter(x=range(20,24),y=M4.results, marker='x', color=M4.color)

plt.legend((M0_points, M1_points, M2_points, M3_points, M4_points),
           (M0.name, M1.name, M2.name, M3.name, M4.name),
           scatterpoints=1,
           loc='best',
           ncol=3,
           fontsize=8)

plt.xlabel('iteration number')
plt.ylabel('energy for specific vector from a mub')
plt.title('H2 Energy Landscape')

plt.show()

# %% [markdown]
# ### iterations around specific basis mubs vectors

# %%
v0 = M1_vectors[1]
print(v0)
# Out:
# [ 0.5+0.j  0.5+0.j -0.5+0.j -0.5+0.j]

# %%
v1 = np.vectorize(complex)([np.sqrt(0.24),0.5,-np.sqrt(0.26),-0.5])
print(v1)
# Out:
# [ 0.48989795+0.j  0.5       +0.j -0.50990195+0.j -0.5       +0.j]

# %%
pauli_coeffs, pauli_strings = transfrom_hamiltonian_into_pauli_strings(H2_molecule_Hamiltonian_2_qubits)
ansatz_state = get_full_entangelment_ansatz(QUBITS_NUM, thetas, v0)

L = get_expectation_value(ansatz_state, pauli_coeffs, pauli_strings)
print(L)
# Out:
# Result(backend_name='qasm_simulator', backend_version='0.11.1', qobj_id='f7aa5e1a-63e6-4e31-a5e3-c81e83b339fd', job_id='8731451f-9f64-48d0-8d55-b90b64ffaa4a', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 526, '0x1': 234, '0x2': 235, '0x3': 29}), header=QobjExperimentHeader(clbit_labels=[['meas', 0], ['meas', 1]], creg_sizes=[['meas', 2]], global_phase=1.2719703568328047, memory_slots=2, metadata={}, n_qubits=2, name='circuit-75286', qreg_sizes=[['qubit', 2]], qubit_labels=[['qubit', 0], ['qubit', 1]]), status=DONE, seed_simulator=567766323, metadata={'batched_shots_optimization': False, 'method': 'statevector', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'sample_measure_time': 0.002539, 'input_qubit_map': [[0, 0], [1, 1]], 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'fusion': {'enabled': True, 'threshold': 14, 'max_fused_qubits': 5, 'applied': False}}, time_taken=0.0064261)], date=2022-12-09T15:21:02.614885, status=COMPLETED, header=None, metadata={'parallel_experiments': 1, 'omp_enabled': True, 'max_memory_mb': 16110, 'max_gpu_memory_mb': 0, 'num_processes_per_experiments': 1, 'time_taken_load_qobj': 0.0005152, 'mpi_rank': 0, 'num_mpi_processes': 1, 'time_taken_execute': 0.006629, 'time_taken': 0.0071649}, time_taken=0.007054567337036133)
# {'00': 0.513671875, '01': 0.228515625, '10': 0.2294921875, '11': 0.0283203125}
# Result(backend_name='qasm_simulator', backend_version='0.11.1', qobj_id='1a9efc2c-d802-47dd-952b-f2fb3b712972', job_id='88f5e56e-9250-4200-86f9-68259ef44978', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x2': 242, '0x0': 481, '0x1': 271, '0x3': 30}), header=QobjExperimentHeader(clbit_labels=[['meas', 0], ['meas', 1]], creg_sizes=[['meas', 2]], global_phase=1.2719703568328047, memory_slots=2, metadata={}, n_qubits=2, name='circuit-75286', qreg_sizes=[['qubit', 2]], qubit_labels=[['qubit', 0], ['qubit', 1]]), status=DONE, seed_simulator=31387045, metadata={'batched_shots_optimization': False, 'method': 'statevector', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'sample_measure_time': 0.0008585, 'input_qubit_map': [[0, 0], [1, 1]], 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'fusion': {'enabled': True, 'threshold': 14, 'max_fused_qubits': 5, 'applied': False}}, time_taken=0.0104692)], date=2022-12-09T15:21:02.689770, status=COMPLETED, header=None, metadata={'parallel_experiments': 1, 'omp_enabled': True, 'max_memory_mb': 16110, 'max_gpu_memory_mb': 0, 'num_processes_per_experiments': 1, 'time_taken_load_qobj': 0.0002996, 'mpi_rank': 0, 'num_mpi_processes': 1, 'time_taken_execute': 0.0106256, 'time_taken': 0.0109436}, time_taken=0.01150822639465332)
# {'00': 0.4697265625, '01': 0.2646484375, '10': 0.236328125, '11': 0.029296875}
# Result(backend_name='qasm_simulator', backend_version='0.11.1', qobj_id='332f6ddc-e657-423a-8988-32fe35c7488d', job_id='f3e4c23b-6545-4c5c-9213-b6095114f5f4', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x2': 259, '0x0': 490, '0x3': 26, '0x1': 249}), header=QobjExperimentHeader(clbit_labels=[['meas', 0], ['meas', 1]], creg_sizes=[['meas', 2]], global_phase=1.2719703568328047, memory_slots=2, metadata={}, n_qubits=2, name='circuit-75286', qreg_sizes=[['qubit', 2]], qubit_labels=[['qubit', 0], ['qubit', 1]]), status=DONE, seed_simulator=698996335, metadata={'batched_shots_optimization': False, 'method': 'statevector', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'sample_measure_time': 0.0009263, 'input_qubit_map': [[0, 0], [1, 1]], 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'fusion': {'enabled': True, 'threshold': 14, 'max_fused_qubits': 5, 'applied': False}}, time_taken=0.0045815)], date=2022-12-09T15:21:02.763812, status=COMPLETED, header=None, metadata={'parallel_experiments': 1, 'omp_enabled': True, 'max_memory_mb': 16110, 'max_gpu_memory_mb': 0, 'num_processes_per_experiments': 1, 'time_taken_load_qobj': 0.0004224, 'mpi_rank': 0, 'num_mpi_processes': 1, 'time_taken_execute': 0.0048062, 'time_taken': 0.005251}, time_taken=0.0060307979583740234)
# {'00': 0.478515625, '01': 0.2431640625, '10': 0.2529296875, '11': 0.025390625}
# Result(backend_name='qasm_simulator', backend_version='0.11.1', qobj_id='83bd0f8e-beea-4145-a37c-e22107ef6e4c', job_id='f307f676-cc23-42a5-b710-aad9841ffeec', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x2': 239, '0x0': 502, '0x1': 251, '0x3': 32}), header=QobjExperimentHeader(clbit_labels=[['meas', 0], ['meas', 1]], creg_sizes=[['meas', 2]], global_phase=1.2719703568328047, memory_slots=2, metadata={}, n_qubits=2, name='circuit-75286', qreg_sizes=[['qubit', 2]], qubit_labels=[['qubit', 0], ['qubit', 1]]), status=DONE, seed_simulator=3725665412, metadata={'batched_shots_optimization': False, 'method': 'statevector', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'sample_measure_time': 0.0008324, 'input_qubit_map': [[0, 0], [1, 1]], 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'fusion': {'enabled': True, 'threshold': 14, 'max_fused_qubits': 5, 'applied': False}}, time_taken=0.0042188)], date=2022-12-09T15:21:02.832186, status=COMPLETED, header=None, metadata={'parallel_experiments': 1, 'omp_enabled': True, 'max_memory_mb': 16110, 'max_gpu_memory_mb': 0, 'num_processes_per_experiments': 1, 'time_taken_load_qobj': 0.0002824, 'mpi_rank': 0, 'num_mpi_processes': 1, 'time_taken_execute': 0.0043579, 'time_taken': 0.0046531}, time_taken=0.004998922348022461)
# {'00': 0.490234375, '01': 0.2451171875, '10': 0.2333984375, '11': 0.03125}
# -0.8043021799620418

# %% [markdown]
# ## Transverse Ising Model 2 qubits

# %%
transverse_ising_2_qubits = 0.13755727363376802 * (I^X) \
                            + 0.43305656297810435 * (X^I) \
                            + 0.8538597608997253 * (Z^Z)

# %%
for basis in mubs_d_5:
    basis.restart_results()
    for vector in basis.basis_vectors:
        pauli_coeffs, pauli_strings = transfrom_hamiltonian_into_pauli_strings(transverse_ising_2_qubits)
        ansatz_state = get_full_entangelment_ansatz(QUBITS_NUM, thetas, vector)

        L = get_expectation_value(ansatz_state, pauli_coeffs, pauli_strings)
        basis.add_result(L)
# Out:
# Result(backend_name='qasm_simulator', backend_version='0.11.1', qobj_id='0bff5ade-3f0e-43f9-ae6f-a226fa3c570d', job_id='0bbded0d-67f1-45e9-a157-be73b65d5278', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x2': 348, '0x0': 627, '0x3': 46, '0x1': 3}), header=QobjExperimentHeader(clbit_labels=[['meas', 0], ['meas', 1]], creg_sizes=[['meas', 2]], global_phase=0.7570115660269829, memory_slots=2, metadata={}, n_qubits=2, name='circuit-66506', qreg_sizes=[['qubit', 2]], qubit_labels=[['qubit', 0], ['qubit', 1]]), status=DONE, seed_simulator=858641276, metadata={'batched_shots_optimization': False, 'method': 'statevector', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'sample_measure_time': 0.0009662, 'input_qubit_map': [[0, 0], [1, 1]], 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'fusion': {'enabled': True, 'threshold': 14, 'max_fused_qubits': 5, 'applied': False}}, time_taken=0.0053843)], date=2022-12-09T15:19:25.095901, status=COMPLETED, header=None, metadata={'parallel_experiments': 1, 'omp_enabled': True, 'max_memory_mb': 16110, 'max_gpu_memory_mb': 0, 'num_processes_per_experiments': 1, 'time_taken_load_qobj': 0.0004842, 'mpi_rank': 0, 'num_mpi_processes': 1, 'time_taken_execute': 0.0055878, 'time_taken': 0.0060944}, time_taken=0.007167339324951172)
# {'00': 0.6123046875, '01': 0.0029296875, '10': 0.33984375, '11': 0.044921875}
# Result(backend_name='qasm_simulator', backend_version='0.11.1', qobj_id='c6a1a973-ea74-4805-afd7-1953237909c6', job_id='2570780a-c9e4-462c-8ab8-ac995d820b6a', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 179, '0x2': 463, '0x3': 299, '0x1': 83}), header=QobjExperimentHeader(clbit_labels=[['meas', 0], ['meas', 1]], creg_sizes=[['meas', 2]], global_phase=3.604526875896462, memory_slots=2, metadata={}, n_qubits=2, name='circuit
success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x2': 355, '0x1': 352, '0x0': 97, '0x3': 220}), header=QobjExperimentHeader(clbit_labels=[['meas', 0], ['meas', 1]], creg_sizes=[['meas', 2]], global_phase=0.7570115660269829, memory_slots=2, metadata={}, n_qubits=2, name='circuit-74847', qreg_sizes=[['qubit', 2]], qubit_labels=[['qubit', 0], ['qubit', 1]]), status=DONE, seed_simulator=1749802624, metadata={'batched_shots_optimization': False, 'method': 'statevector', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'sample_measure_time': 0.0009859, 'input_qubit_map': [[0, 0], [1, 1]], 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'fusion': {'enabled': True, 'threshold': 14, 'max_fused_qubits': 5, 'applied': False}}, time_taken=0.0060112)], date=2022-12-09T15:19:38.554282, status=COMPLETED, header=None, metadata={'parallel_experiments': 1, 'omp_enabled': True, 'max_memory_mb': 16110, 'max_gpu_memory_mb': 0, 'num_processes_per_experiments': 1, 'time_taken_load_qobj': 0.0003228, 'mpi_rank': 0, 'num_mpi_processes': 1, 'time_taken_execute': 0.0061763, 'time_taken': 0.0065154}, time_taken=0.006958723068237305)
# {'00': 0.0947265625, '01': 0.34375, '10': 0.3466796875, '11': 0.21484375}
# Result(backend_name='qasm_simulator', backend_version='0.11.1', qobj_id='22a3a473-f81d-44ac-ab88-195d63cedba9', job_id='b51f63ab-1b0b-4716-8056-d90d387672e1', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 365, '0x1': 226, '0x2': 145, '0x3': 288}), header=QobjExperimentHeader(clbit_labels=[['meas', 0], ['meas', 1]], creg_sizes=[['meas', 2]], global_phase=3.604526875896462, memory_slots=2, metadata={}, n_qubits=2, name='circuit-74847', qreg_sizes=[['qubit', 2]], qubit_labels=[['qubit', 0], ['qubit', 1]]), status=DONE, seed_simulator=3812404822, metadata={'batched_shots_optimization': False, 'method': 'statevector', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'sample_measure_time': 0.0008426, 'input_qubit_map': [[0, 0], [1, 1]], 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'fusion': {'enabled': True, 'threshold': 14, 'max_fused_qubits': 5, 'applied': False}}, time_taken=0.0046409)], date=2022-12-09T15:19:38.663483, status=COMPLETED, header=None, metadata={'parallel_experiments': 1, 'omp_enabled': True, 'max_memory_mb': 16110, 'max_gpu_memory_mb': 0, 'num_processes_per_experiments': 1, 'time_taken_load_qobj': 0.0004509, 'mpi_rank': 0, 'num_mpi_processes': 1, 'time_taken_execute': 0.0047884, 'time_taken': 0.005255}, time_taken=0.005891084671020508)
# {'00': 0.3564453125, '01': 0.220703125, '10': 0.1416015625, '11': 0.28125}
# Result(backend_name='qasm_simulator', backend_version='0.11.1', qobj_id='4b4de75c-7b8b-45de-8e3c-5d2fc2778d0a', job_id='522b8e08-d0ad-4a2d-b249-bf9d06c49a51', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x2': 399, '0x0': 48, '0x1': 556, '0x3': 21}), header=QobjExperimentHeader(clbit_labels=[['meas', 0], ['meas', 1]], creg_sizes=[['meas', 2]], global_phase=1.2719703568328047, memory_slots=2, metadata={}, n_qubits=2, name='circuit-74847', qreg_sizes=[['qubit', 2]], qubit_labels=[['qubit', 0], ['qubit', 1]]), status=DONE, seed_simulator=1991028084, metadata={'batched_shots_optimization': False, 'method': 'statevector', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'sample_measure_time': 0.0034067, 'input_qubit_map': [[0, 0], [1, 1]], 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'fusion': {'enabled': True, 'threshold': 14, 'max_fused_qubits': 5, 'applied': False}}, time_taken=0.0081797)], date=2022-12-09T15:19:38.744918, status=COMPLETED, header=None, metadata={'parallel_experiments': 1, 'omp_enabled': True, 'max_memory_mb': 16110, 'max_gpu_memory_mb': 0, 'num_processes_per_experiments': 1, 'time_taken_load_qobj': 0.0002786, 'mpi_rank': 0, 'num_mpi_processes': 1, 'time_taken_execute': 0.0083332, 'time_taken': 0.008629}, time_taken=0.010133981704711914)
# {'00': 0.046875, '01': 0.54296875, '10': 0.3896484375, '11': 0.0205078125}

# %%
M0_points = plt.scatter(x=range(1,5),y=M0.results, marker='x', color=M0.color)
M1_points = plt.scatter(x=range(5,9),y=M1.results, marker='x', color=M1.color)
M2_points = plt.scatter(x=range(10,14),y=M2.results, marker='x', color=M2.color)
M3_points = plt.scatter(x=range(15,19),y=M3.results, marker='x', color=M3.color)
M4_points = plt.scatter(x=range(20,24),y=M4.results, marker='x', color=M4.color)

plt.legend((M0_points, M1_points, M2_points, M3_points, M4_points),
           (M0.name, M1.name, M2.name, M3.name, M4.name),
           scatterpoints=1,
           loc='best',
           ncol=3,
           fontsize=8)

plt.xlabel('iteration number')
plt.ylabel('energy for specific vector from a mub')
plt.title('Transverse Ising Model Energy Landscape')

plt.show()
